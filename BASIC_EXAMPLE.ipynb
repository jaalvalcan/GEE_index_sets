# %% [markdown]
# <a href="https://colab.research.google.com/github/jaalvalcan/GEE_index_sets/blob/main/BASIC_EXAMPLE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import ee

# %%
ee.Authenticate()
ee.Initialize(project='ee-jaalvalcan')

# %%
import geemap

# %%
map = geemap.Map(basemap = 'SATELLITE')
map

# %%
roi = map.draw_last_feature.geometry()

roi
