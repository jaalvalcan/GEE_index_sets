# %% [markdown]
# <a href="https://colab.research.google.com/github/jaalvalcan/GEE_index_sets/blob/main/wetland__sam3_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install "segment-geospatial[samgeo3]"

# %%
# %pip install transformers==5.0.0rc0

# %%
import leafmap
from samgeo import SamGeo3, download_file

# %%
url = "https://drive.google.com/file/d/10Yzn74tqfY8C3pBD45PxHZmKr6EZWIUw/view?usp=sharing"
image_path = download_file(url)

# %%
m = leafmap.Map()
m.add_raster(image_path, layer_name="Image")
m

# %%
from huggingface_hub import login
login()

# %%
sam3 = SamGeo3(
    backend="transformers", device=None, checkpoint_path=None, load_from_HF=True
)

# %%
sam3.set_image(image_path)

# %%
sam3.generate_masks(prompt="water")

# %%
sam3.save_masks("masks.tif")

# %%
sam3.show_anns()

# %%
sam3.show_masks()

# %%
sam3.show_map(height="700px", min_size=10)
